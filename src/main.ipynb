# %%
from src.analysis.processing import AXCPT
import pandas as pd
from src.config import CONFIG

# %%
# Load all sessions
sessions = AXCPT.readAllSessions()
# Out:
# DEBUG    :: src.analysis.processing :: Loading 3 sessions: record_p-1_b_2023-12-07_16-43-31, record_p-2_2023-12-14_14-39-01, record_p-3_2023-12-15_15-48-43
# DEBUG    :: src.analysis.processing :: Loading data from file: C:\Users\HP User\source\repos\ov_axcpt\ov_experiment/scenarios/data\record_p-1_b_2023-12-07_16-43-31\record_p-1_b_2023-12-07_16-43-31.gdf
# Extracting EDF parameters from C:\Users\HP User\source\repos\ov_axcpt\ov_experiment\scenarios\data\record_p-1_b_2023-12-07_16-43-31\record_p-1_b_2023-12-07_16-43-31.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# Channel 1, Channel 2, Channel 3, Channel 4, Channel 5, Channel 6, Channel 7, Channel 8, Channel 9, Channel 10, Channel 11, Channel 12, Channel 13, Channel 14, Channel 15, Channel 16, Channel 17, Channel 18, Channel 19, Channel 20, Channel 21, Channel 22, Channel 23, Channel 24, Channel 25, Channel 26, Channel 27, Channel 28, Channel 29, Channel 30, Channel 31, Channel 32, Channel 33, Channel 34, Channel 35, Channel 36, Channel 37, Channel 38, Channel 39, Channel 40, Channel 41, Channel 42, Channel 43, Channel 44, Channel 45, Channel 46, Channel 47, Channel 48, Channel 49, Channel 50, Channel 51, Channel 52, Channel 53, Channel 54, Channel 55, Channel 56, Channel 57, Channel 58, Channel 59, Channel 60, Channel 61, Channel 62, Channel 63, Channel 64, Channel 65, Channel 66
# Creating raw.info structure...
# Used Annotations descriptions: ['27', '32769', '32770', '32773', '32774', '32780', '33025', '33026', '33027', '33028', '33029', '33031', '33032', '33033', '33040', '33041', '33042', '33043', '33044', '33045', '33046', '33047', '33048', '33049', '33056', '33057', '33058', '33059', '33060', '33061', '33062', '33184', '33279', '769', '770', '786', '898']
# Adding metadata with 45 columns
# 192 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 192 events and 1537 original time points ...
# 0 bad epochs dropped
# DEBUG    :: src.analysis.processing :: Loading data from file: C:\Users\HP User\source\repos\ov_axcpt\ov_experiment/scenarios/data\record_p-2_2023-12-14_14-39-01\record_p-2_2023-12-14_14-39-01.gdf
# Extracting EDF parameters from C:\Users\HP User\source\repos\ov_axcpt\ov_experiment\scenarios\data\record_p-2_2023-12-14_14-39-01\record_p-2_2023-12-14_14-39-01.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# 1Z, 2Z, 3Z, 4Z, 6Z, 7Z, 8Z, 9Z, 1L, 2L, 3L, 4L, 5L, 6L, 7L, 8L, 9L, 10L, 11L, 1R, 2R, 3R, 4R, 5R, 6R, 7R, 8R, 9R, 10R, 11R, 1LA, 2LA, 3LA, 1LB, 2LB, 3LB, 4LB, 5LB, 1LC, 2LC, 3LC, 4LC, 5LC, 1LD, 2LD, 3LD, 4LD, 1RA, 2RA, 3RA, 1RB, 2RB, 3RB, 4RB, 5RB, 1RC, 2RC, 3RC, 4RC, 5RC, 1RD, 2RD, 3RD, 4RD, Tgt, SC
# Creating raw.info structure...
# Used Annotations descriptions: ['27', '32769', '32770', '32773', '32774', '32775', '32776', '32780', '33025', '33026', '33027', '33028', '33029', '33030', '33031', '33032', '33033', '33040', '33041', '33042', '33043', '33045', '33046', '33047', '33048', '33049', '33056', '33057', '33058', '33059', '33060', '33061', '33062', '33184', '33279', '769', '770', '786', '898']
# Reading 0 ... 442783  =      0.000 ...   885.566 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 59 - 61 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 59.35
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 59.10 Hz)
# - Upper passband edge: 60.65 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 60.90 Hz)
# - Filter length: 3301 samples (6.602 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# Filtering a subset of channels. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.3 - 70 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.30
# - Lower transition bandwidth: 0.30 Hz (-6 dB cutoff frequency: 0.15 Hz)
# - Upper passband edge: 70.00 Hz
# - Upper transition bandwidth: 17.50 Hz (-6 dB cutoff frequency: 78.75 Hz)
# - Filter length: 5501 samples (11.002 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# Adding metadata with 47 columns
# 192 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 192 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 2 columns
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1501 original time points ...
# 0 bad epochs dropped
# DEBUG    :: src.analysis.processing :: Loading data from file: C:\Users\HP User\source\repos\ov_axcpt\ov_experiment/scenarios/data\record_p-3_2023-12-15_15-48-43\record_p-3_2023-12-15_15-48-43.gdf
# Extracting EDF parameters from C:\Users\HP User\source\repos\ov_axcpt\ov_experiment\scenarios\data\record_p-3_2023-12-15_15-48-43\record_p-3_2023-12-15_15-48-43.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# 1Z, 2Z, 3Z, 4Z, 6Z, 7Z, 8Z, 9Z, 1L, 2L, 3L, 4L, 5L, 6L, 7L, 8L, 9L, 10L, 11L, 1R, 2R, 3R, 4R, 5R, 6R, 7R, 8R, 9R, 10R, 11R, 1LA, 2LA, 3LA, 1LB, 2LB, 3LB, 4LB, 5LB, 1LC, 2LC, 3LC, 4LC, 5LC, 1LD, 2LD, 3LD, 4LD, 1RA, 2RA, 3RA, 1RB, 2RB, 3RB, 4RB, 5RB, 1RC, 2RC, 3RC, 4RC, 5RC, 1RD, 2RD, 3RD, 4RD, Tgt, SC
# Creating raw.info structure...
# Used Annotations descriptions: ['27', '32769', '32770', '32773', '32774', '32775', '32776', '32780', '33025', '33026', '33027', '33028', '33029', '33030', '33031', '33032', '33033', '33040', '33041', '33042', '33043', '33044', '33045', '33046', '33047', '33048', '33049', '33056', '33057', '33058', '33059', '33060', '33061', '33062', '33184', '33185', '33200', '33279', '769', '770', '786', '898']
# Reading 0 ... 428799  =      0.000 ...   857.598 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 59 - 61 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 59.35
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 59.10 Hz)
# - Upper passband edge: 60.65 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 60.90 Hz)
# - Filter length: 3301 samples (6.602 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# Filtering a subset of channels. The highpass and lowpass values in the measurement info will not be updated.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.3 - 70 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.30
# - Lower transition bandwidth: 0.30 Hz (-6 dB cutoff frequency: 0.15 Hz)
# - Upper passband edge: 70.00 Hz
# - Upper transition bandwidth: 17.50 Hz (-6 dB cutoff frequency: 78.75 Hz)
# - Filter length: 5501 samples (11.002 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# Adding metadata with 50 columns
# 192 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 192 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 2 columns
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1501 original time points ...
# 0 bad epochs dropped

# %%
# Get the classifier data for each session
cDatas = [s.getClassifierData() for s in sessions]
# Out:
# INFO     :: src.analysis.processing :: Getting features for 181 epochs and 13 channels of data
# INFO     :: src.analysis.processing :: Getting metric 'ApEn'
# DEBUG    :: src.analysis.processing :: Loaded 2353 of 2353 items from cache for metric 'ApEn'
# DEBUG    :: src.analysis.processing :: Done getting metric 'ApEn'. Approximate time taken: 0:00:00.015000
# INFO     :: src.analysis.processing :: Getting metric 'SampEn'
# DEBUG    :: src.analysis.processing :: Loaded 2353 of 2353 items from cache for metric 'SampEn'
# DEBUG    :: src.analysis.processing :: Done getting metric 'SampEn'. Approximate time taken: 0:00:00
# INFO     :: src.analysis.processing :: Getting metric 'FE'
# DEBUG    :: src.analysis.processing :: Loaded 2353 of 2353 items from cache for metric 'FE'
# DEBUG    :: src.analysis.processing :: Done getting metric 'FE'. Approximate time taken: 0:00:00.016000
# INFO     :: src.analysis.processing :: Getting metric 'MSE'
# DEBUG    :: src.analysis.processing :: Loaded 2353 of 2353 items from cache for metric 'MSE'
# DEBUG    :: src.analysis.processing :: Done getting metric 'MSE'. Approximate time taken: 0:00:00
# INFO     :: src.analysis.processing :: Getting metric 'MFE'
# DEBUG    :: src.analysis.processing :: Loaded 2353 of 2353 items from cache for metric 'MFE'
# DEBUG    :: src.analysis.processing :: Done getting metric 'MFE'. Approximate time taken: 0:00:00.016000
# INFO     :: src.analysis.processing :: Getting features for 192 epochs and 13 channels of data
# INFO     :: src.analysis.processing :: Getting features for 60 epochs and 13 channels of baseline
# INFO     :: src.analysis.processing :: Getting metric 'ApEn'
# DEBUG    :: src.analysis.processing :: Loaded 3276 of 3276 items from cache for metric 'ApEn'
# DEBUG    :: src.analysis.processing :: Done getting metric 'ApEn'. Approximate time taken: 0:00:00
# INFO     :: src.analysis.processing :: Getting metric 'SampEn'
# DEBUG    :: src.analysis.processing :: Loaded 3276 of 3276 items from cache for metric 'SampEn'
# DEBUG    :: src.analysis.processing :: Done getting metric 'SampEn'. Approximate time taken: 0:00:00.016000
# INFO     :: src.analysis.processing :: Getting metric 'FE'
# DEBUG    :: src.analysis.processing :: Loaded 3276 of 3276 items from cache for metric 'FE'
# DEBUG    :: src.analysis.processing :: Done getting metric 'FE'. Approximate time taken: 0:00:00.016000
# INFO     :: src.analysis.processing :: Getting metric 'MSE'
# DEBUG    :: src.analysis.processing :: Loaded 3276 of 3276 items from cache for metric 'MSE'
# DEBUG    :: src.analysis.processing :: Done getting metric 'MSE'. Approximate time taken: 0:00:00.015000
# INFO     :: src.analysis.processing :: Getting metric 'MFE'
# DEBUG    :: src.analysis.processing :: Loaded 3276 of 3276 items from cache for metric 'MFE'
# DEBUG    :: src.analysis.processing :: Done getting metric 'MFE'. Approximate time taken: 0:00:00
# INFO     :: src.analysis.processing :: Getting features for 191 epochs and 13 channels of data
# INFO     :: src.analysis.processing :: Getting features for 60 epochs and 13 channels of baseline
# INFO     :: src.analysis.processing :: Getting metric 'ApEn'
# DEBUG    :: src.analysis.processing :: Loaded 3263 of 3263 items from cache for metric 'ApEn'
# DEBUG    :: src.analysis.processing :: Done getting metric 'ApEn'. Approximate time taken: 0:00:00.016000
# INFO     :: src.analysis.processing :: Getting metric 'SampEn'
# DEBUG    :: src.analysis.processing :: Loaded 3263 of 3263 items from cache for metric 'SampEn'
# DEBUG    :: src.analysis.processing :: Done getting metric 'SampEn'. Approximate time taken: 0:00:00.031000
# INFO     :: src.analysis.processing :: Getting metric 'FE'
# DEBUG    :: src.analysis.processing :: Loaded 3263 of 3263 items from cache for metric 'FE'
# DEBUG    :: src.analysis.processing :: Done getting metric 'FE'. Approximate time taken: 0:00:00.031000
# INFO     :: src.analysis.processing :: Getting metric 'MSE'
# DEBUG    :: src.analysis.processing :: Loaded 3263 of 3263 items from cache for metric 'MSE'
# DEBUG    :: src.analysis.processing :: Done getting metric 'MSE'. Approximate time taken: 0:00:00.031000
# INFO     :: src.analysis.processing :: Getting metric 'MFE'
# DEBUG    :: src.analysis.processing :: Loaded 3263 of 3263 items from cache for metric 'MFE'
# DEBUG    :: src.analysis.processing :: Done getting metric 'MFE'. Approximate time taken: 0:00:00.032000

# %%
# Combine classifier data into a single dataframe
cData = pd.concat(
    cDatas,
    keys=[s.info["sessionName"] for s in sessions],
    names=["session"]
    )
cData
# Out:
#                                                     label  features            \
#                                                             ApEn/1L  ApEn/1LA
# session                          type     epoch
# record_p-1_b_2023-12-07_16-43-31 task     0           low  0.229797  1.248169
#                                           1           low  1.340517  1.182164
#                                           2        medium  0.820749  0.959558
#                                           3        medium  0.690257  0.879724
#                                           4        medium  0.238562  0.787514
# ...                                                   ...       ...       ...
# record_p-3_2023-12-15_15-48-43   baseline 55     baseline  0.238305  0.838077
#                                           56     baseline  0.787976  0.940676
#                                           57     baseline  0.257113  0.748344
#                                           58     baseline  0.216387  0.785758
#                                           59     baseline  0.272929  0.792586
#
#                                                                                \
#                                                   ApEn/1R  ApEn/1RA   ApEn/2L
# session                          type     epoch
# record_p-1_b_2023-12-07_16-43-31 task     0      0.300463  1.266556  0.631113
#                                           1      1.263603  0.946602  1.299233
#                                           2      1.025567  0.691603  0.746682
#                                           3      0.576991  1.341344  0.913563
#                                           4      0.300129  0.762280  0.475212
# ...                                                   ...       ...       ...
# record_p-3_2023-12-15_15-48-43   baseline 55     0.219277  0.906633  0.450083
#                                           56     0.871257  0.979240  0.848153
#                                           57     0.232183  0.850392  0.389883
#                                           58     0.180851  0.897248  0.390123
#                                           59     0.238717  0.842578  0.455694
#
#                                                                                \
#                                                  ApEn/2LC   ApEn/2R  ApEn/2RC
# session                          type     epoch
# record_p-1_b_2023-12-07_16-43-31 task     0      0.959969  0.689467  1.153086
#                                           1      0.889846  1.346708  1.540403
#                                           2      1.372558  0.909173  1.068827
#                                           3      0.601516  0.533464  1.132574
#                                           4      0.870436  0.785586  1.204654
# ...                                                   ...       ...       ...
# record_p-3_2023-12-15_15-48-43   baseline 55     0.991129  0.418293  0.967219
#                                           56     0.928224  0.961653  1.006761
#                                           57     0.644352  0.415371  0.692669
#                                           58     0.882740  0.366339  0.899698
#                                           59     0.850430  0.396313  0.840844
#
#                                                            ...            \
#                                                   ApEn/2Z  ...   MFE/1RA
# session                          type     epoch            ...
# record_p-1_b_2023-12-07_16-43-31 task     0      0.951694  ...  0.693759
#                                           1      1.237129  ...  0.437543
#                                           2      0.974971  ...  0.381970
#                                           3      0.835279  ...  0.831854
#                                           4      0.813266  ...  0.432603
# ...                                                   ...  ...       ...
# record_p-3_2023-12-15_15-48-43   baseline 55     0.432056  ...  0.544584
#                                           56     0.818325  ...  0.510401
#                                           57     0.448183  ...  0.448527
#                                           58     0.411624  ...  0.662893
#                                           59     0.446867  ...  0.763428
#
#                                                                                \
#                                                    MFE/2L   MFE/2LC    MFE/2R
# session                          type     epoch
# record_p-1_b_2023-12-07_16-43-31 task     0      0.530612  0.699259  0.625444
#                                           1      0.889537  0.479058  0.855189
#                                           2      0.456020  0.809141  0.673080
#                                           3      0.688284  0.431003  0.362700
#                                           4      0.413614  0.481183  0.498885
# ...                                                   ...       ...       ...
# record_p-3_2023-12-15_15-48-43   baseline 55     0.464828  0.794216  0.410093
#                                           56     0.819179  0.728884  0.819954
#                                           57     0.272619  0.583727  0.353320
#                                           58     0.498666  0.519986  0.406691
#                                           59     0.668214  0.812424  0.545112
#
#                                                                                \
#                                                   MFE/2RC    MFE/2Z   MFE/3LB
# session                          type     epoch
# record_p-1_b_2023-12-07_16-43-31 task     0      0.643107  0.651840  0.645509
#                                           1      0.790959  0.826137  0.467073
#                                           2      0.647720  0.599129  0.558564
#                                           3      0.545736  0.484205  0.818659
#                                           4      0.719010  0.585674  0.658620
# ...                                                   ...       ...       ...
# record_p-3_2023-12-15_15-48-43   baseline 55     0.645224  0.456005  0.362805
#                                           56     0.637283  0.762960  0.376466
#                                           57     0.449221  0.301067  0.405494
#                                           58     0.552747  0.567626  0.362788
#                                           59     0.840994  0.595169  0.505059
#
#
#                                                   MFE/3RB    MFE/4L    MFE/4R
# session                          type     epoch
# record_p-1_b_2023-12-07_16-43-31 task     0      0.305159  0.848418  0.615685
#                                           1      0.475619  0.540518  0.666632
#                                           2      0.851572  0.519825  0.332232
#                                           3      0.264428  0.680069  0.523980
#                                           4      0.580724  0.524704  0.447380
# ...                                                   ...       ...       ...
# record_p-3_2023-12-15_15-48-43   baseline 55     0.561904  0.826562  0.672928
#                                           56     0.595947  0.659090  0.624516
#                                           57     0.318756  0.637914  0.480058
#                                           58     0.630216  0.618673  0.689309
#                                           59     0.813449  0.623718  0.769619
#
# [684 rows x 66 columns]

# %%
cData["label"].value_counts() / len(cData) * 100
# Out:
# label
# medium      40.789474
# high        21.491228
# low         20.175439
# baseline    17.543860
# Name: count, dtype: float64
